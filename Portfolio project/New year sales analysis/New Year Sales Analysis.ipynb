# %% [markdown]
# ## Importing the libraries

# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Loading the dataset

# %%
# Load dataset
df = pd.read_csv("/Users/HP/Desktop/InlineX Global/Portfolio project/New year sales analysis/New Year Sales Data.csv",encoding='latin1')

# First 5 rows
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# 2  23924.0     NaN       NaN
# 3  23912.0     NaN       NaN
# 4  23877.0     NaN       NaN

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %% [markdown]
# ## Data Cleaning

# %%
#Check for null values
df.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
# Dropping unrequired columns
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df.shape
# Out:
# (11239, 13)

# %%
df['Amount'] = df['Amount'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  int64
# dtypes: int64(5), object(8)
# memory usage: 1.2+ MB

# %%
df.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %% [markdown]
# ## Data overview & Summary

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df.nunique()
# Out:
# User_ID             3752
# Cust_name           1250
# Product_ID          2350
# Gender                 2
# Age Group              7
# Age                   81
# Marital_Status         2
# State                 16
# Zone                   5
# Occupation            15
# Product_Category      18
# Orders                 4
# Amount              6583
# dtype: int64

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ## 1. Gender analysis

# %%
## Which gender has higher purchasing power?
sns.countplot(x='Gender', data=df, palette='Set2')
plt.title("Gender Distribution")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5732\3656959164.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='Set2')

# %%
## total purchase amount by gender.
gender_amount = df.groupby('Gender')['Amount'].sum().reset_index()

sns.barplot(x='Gender', y='Amount', data=gender_amount, palette='coolwarm')
plt.title("Total Purchase Amount by Gender")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5732\88848255.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Gender', y='Amount', data=gender_amount, palette='coolwarm')

# %%
## Key Insights
# There are mostly female customers

# %% [markdown]
# ## 2. Age group analysis

# %%
## Which age group has the most purchases, and is there a trend in purchasing power by age?
sns.countplot(x='Age Group', hue = 'Gender',data=df, palette='Set3')
plt.title("Age Group Distribution")
plt.show()

# %%
# total purchases by age group
age_amount = df.groupby('Age Group')['Amount'].sum().reset_index()

sns.barplot(x='Age Group', y='Amount', data=age_amount, palette='viridis')
plt.title("Total Purchase Amount by Age Group")
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5732\2071863688.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Age Group', y='Amount', data=age_amount, palette='viridis')

# %%
## Key Insights
# There is a trend in purchasing power by age as most age group is 26-35. these group people has high purchasing power.

# %% [markdown]
# ## 3.State Analysis

# %%
## Which states generate the highest number of orders?
top_states_orders = df['State'].value_counts().head(10)
top_states_orders
# Out:
# State
# Uttar Pradesh       1944
# Maharashtra         1525
# Karnataka           1304
# Delhi               1104
# Madhya Pradesh       921
# Andhra Pradesh       811
# Himachal Pradesh     608
# Kerala               453
# Haryana              452
# Bihar                434
# Name: count, dtype: int64

# %%
sns.barplot(x=top_states_orders.values, y=top_states_orders.index, palette='magma')
plt.title("Top 10 States by Orders")
plt.xlabel("Number of Orders")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5732\1771760415.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_states_orders.values, y=top_states_orders.index, palette='magma')

# %%
## Which states generate the highest number of revenue?
top_states_amount = df.groupby('State')['Amount'].sum().sort_values(ascending=False).head(10)
top_states_amount
# Out:
# State
# Uttar Pradesh       19374968
# Maharashtra         14427543
# Karnataka           13523540
# Delhi               11603818
# Madhya Pradesh       8101142
# Andhra Pradesh       8037146
# Himachal Pradesh     4963368
# Haryana              4220175
# Bihar                4022757
# Gujarat              3946082
# Name: Amount, dtype: int64

# %%
sns.barplot(x=top_states_amount.values, y=top_states_amount.index, palette='inferno')
plt.title("Top 10 States by Revenue")
plt.xlabel("Total Amount")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5732\2825243904.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_states_amount.values, y=top_states_amount.index, palette='inferno')

# %%
## Key Insights
# Most of the orders are from Uttar Pradesh followed by Maharashtra and many more.

# %% [markdown]
# ## 4. Marital Status Analysis

# %%
## How does marital status affect purchasing behavior?
sns.countplot(x='Marital_Status', data=df, palette='Set1')
plt.title("Marital Status Distribution")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5732\1066078551.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Marital_Status', data=df, palette='Set1')

# %%
marital_amount = df.groupby(['Marital_Status', 'Gender'])['Amount'].sum().reset_index()

sns.barplot(x='Marital_Status', y='Amount', hue='Gender', data=marital_amount)
plt.title("Amount Spent by Marital Status and Gender")
plt.show()

# %%
## Key Insights
# Most of the items are purchased by unmarried category and by females

# %% [markdown]
# ## 5. Occupation Analysis

# %%
## Which occupations contribute most to sales?
plt.figure(figsize=(20,6))
sns.countplot(x='Occupation', data=df, palette='Set2')
plt.title("Occupation Distribution")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5732\788750858.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Occupation', data=df, palette='Set2')

# %%
occupation_amount = df.groupby('Occupation')['Amount'].sum().sort_values(ascending=False).reset_index()

plt.figure(figsize=(20,5))
sns.barplot(x='Occupation', y='Amount', data=occupation_amount, palette='Set3')
plt.title("Total Sales by Occupation")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5732\3595688094.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Occupation', y='Amount', data=occupation_amount, palette='Set3')

# %%
## Key Insights
# IT Sector occupation contributes more to the sales followed by healthcare and aviation and many more.

# %% [markdown]
# ## 6. Product Category Analysis

# %%
## What product categories are the most popular, and which ones generate the most revenue?
plt.figure(figsize=(20,6))
sns.countplot(x='Product_Category', data=df, palette='Set1')
plt.title("Product Category Distribution")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5732\1591611101.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Product_Category', data=df, palette='Set1')

# %%
product_amount = df.groupby('Product_Category')['Amount'].sum().sort_values(ascending=False).head(10).reset_index()

plt.figure(figsize=(20,5))
sns.barplot(x='Product_Category', y='Amount', data=product_amount, palette='Set2')
plt.title("Top Product Categories by Revenue")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5732\2290877710.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Product_Category', y='Amount', data=product_amount, palette='Set2')

# %%
## Key Insights
# The most famous product category is Food which generates most of the revenue.
